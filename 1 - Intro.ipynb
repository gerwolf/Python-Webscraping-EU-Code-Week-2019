# %% [markdown]
# # Welcome to EU Code Week 2019!

# %%
from IPython.display import Image
Image("CodeWeek_Logo2019.png")

# %% [markdown]
# ### Date: 9th October 2019
# ### Place: Wirtschaftswissenschaftliche Fakultät der Humboldt-Universität zu Berlin, Spandauer Str. 1, 10178 Berlin, Room 21A
# ### Your presenter: Gerome Wolf

# %% [markdown]
# ## About me:
#
# - Economics student who loves coding, hacking, innovation, DATA
# - Did my bachelor here at Humboldt-University, finished my MSc in Econ at UCL this year
# - Worked at HelloFresh in BI, commercial bank and central bank (state of innovation and technology...has scope for improvement)
# - Started Python programming two years ago, worked with many types of data (time series, spatial, music, images) in a seminar on ... webscraping :D

# %% [markdown]
# # Timeline
#
# ## First block
#
# - 10:30 first break <br>
# - 11:30 second break <br>
# - 12:30 lunch break <br>
#
# ## Second block
#
# - start: 13:30 <br>
# - break: 14:30 <br>
# - end: 15:30

# %% [markdown]
# # Twitter: hashtag: CodeWeek <br>
# @CodeWeekEU

# %% [markdown]
# ## Now it's your turn!

# %% [markdown]
# 1. Name <br>
# 2. Background (Student, Professional) <br>
# 3. Why are you here? <br>
# 4. Do you have a specific use case / project in mind? <br>
# 5. Previous coding experience? <br>
# 6. How did you learn about the event?
